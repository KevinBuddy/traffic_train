# %%
from PIL import Image
import os
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def addfiletolist(rootdir,img,val,id):
    list = os.listdir(rootdir) #列出文件夹下所有的目录与文件
    for i in range(0,len(list)):
        path = os.path.join(rootdir,list[i])
        if os.path.isfile(path):
            img1 = Image.open(path)  
            img1=img1.resize((32,32))
            arr1=np.array(img1)
            img.append(arr1)
            #print(arr1.shape)
            #print(path)
            #print(np.array(img).shape)
            val.append(id)
X_all=[]
y_all=[]
rootdir = 'image_red'
addfiletolist(rootdir,X_all,y_all,0)
rootdir = 'image_green'
addfiletolist(rootdir,X_all,y_all,1)
rootdir = 'image_yellow'
addfiletolist(rootdir,X_all,y_all,2)
rootdir = 'image_other'
addfiletolist(rootdir,X_all,y_all,3)

import numpy as np
import pandas
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results

# TODO: Number of training examples
X_all=np.array(X_all)
y_all=np.array(y_all)

n_train = len(X_all)

# TODO: Number of validation examples
#n_validation = len(X_valid)

# TODO: Number of testing examples.
#n_test = len(X_test)

# TODO: What's the shape of an traffic sign image?
image_shape = X_all.shape

# TODO: How many unique classes/labels there are in the dataset.
n_classes = max(y_all)+1

print("Number of training examples =", n_train)
#print("Number of validation examples =", n_validation)
#print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)

### Preprocess the data here. It is required to normalize the data. Other preprocessing steps could include 
### converting to grayscale, etc.
### Feel free to use as many code cells as needed.
from sklearn.utils import shuffle
from PIL import Image, ImageFilter
from PIL import Image, ImageFilter

class MyGaussianBlur(ImageFilter.Filter):
    name = "GaussianBlur"

    def __init__(self, radius=2, bounds=None):
        self.radius = radius
        self.bounds = bounds

    def filter(self, image):
        if self.bounds:
            clips = image.crop(self.bounds).gaussian_blur(self.radius)
            image.paste(clips, self.bounds)
            return image
        else:
            return image.gaussian_blur(self.radius)
X_train, y_train = shuffle(X_all, y_all)
X_valid=X_train[n_train-200:n_train]
y_valid=y_train[n_train-200:n_train]
X_train=X_train[0:n_train-200]
y_train=y_train[0:n_train-200]
n_train=n_train-200

import tensorflow as tf
from tensorflow.contrib.layers import flatten
def LeNet(x):    
    # Arguments used for tf.truncated_normal, randomly defines variables for the weights and biases for each layer
    mu = 0
    sigma = 0.1
    
    # TODO: Layer 1: Convolutional. Input = 32x32x1. Output = 28x28x6.
    conv1_w=tf.Variable(tf.truncated_normal(shape=(5, 5, 3, 6),mean=mu,stddev=sigma))
    conv1_b=tf.Variable(tf.zeros(6))
    conv1=tf.nn.conv2d(x,conv1_w,strides=[1,1,1,1],padding='VALID')+conv1_b
    # TODO: Activation.
    conv1=tf.nn.relu(conv1)
    # TODO: Pooling. Input = 28x28x6. Output = 14x14x6.
    conv1=tf.nn.max_pool(conv1,ksize=[1,2,2,1],strides=[1,2,2,1],padding='VALID')
    # TODO: Layer 2: Convolutional. Output = 10x10x16.
    conv2_w=tf.Variable(tf.truncated_normal(shape=(5, 5, 6, 16),mean=mu,stddev=sigma))
    conv2_b=tf.Variable(tf.zeros(16))
    conv2=tf.nn.conv2d(conv1,conv2_w,strides=[1,1,1,1],padding='VALID')+conv2_b
    
    # TODO: Activation.
    conv2=tf.nn.relu(conv2)
    # TODO: Pooling. Input = 10x10x16. Output = 5x5x16.
    conv2=tf.nn.max_pool(conv2,ksize=[1,2,2,1],strides=[1,2,2,1],padding='VALID')

    # TODO: Flatten. Input = 5x5x16. Output = 400.
    fe0=flatten(conv2)
    # TODO: Layer 3: Fully Connected. Input = 400. Output = 120.
    fc1_w=tf.Variable(tf.truncated_normal(shape=(400,120),mean=mu,stddev=sigma))
    fc1_b=tf.Variable(tf.zeros(120))
    fc1=tf.matmul(fe0,fc1_w)+fc1_b
    
    # TODO: Activation.
    fc1=tf.nn.relu(fc1)
    # TODO: Layer 4: Fully Connected. Input = 120. Output = 84.
    fc2_w=tf.Variable(tf.truncated_normal(shape=(120,84),mean=mu,stddev=sigma))
    fc2_b=tf.Variable(tf.zeros(84))
    fc2=tf.matmul(fc1,fc2_w)+fc2_b
   
    # TODO: Activation.
    fc2=tf.nn.relu(fc2)
    # TODO: Layer 5: Fully Connected. Input = 84. Output = 10.
    fc3_w=tf.Variable(tf.truncated_normal(shape=(84,43),mean=mu,stddev=sigma))
    fc3_b=tf.Variable(tf.zeros(43))
    logits_temp=tf.matmul(fc2,fc3_w)+fc3_b
    
    return logits_temp
x = tf.placeholder(tf.float32, (None, 32, 32, 3))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)
rate = 0.001

logits = LeNet(x)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=one_hot_y, logits=logits)
topk = tf.nn.softmax(logits)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
saver = tf.train.Saver()

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

def evaluate_index(X_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    out = sess.run(tf.argmax(logits, 1), feed_dict={x: X_data})
    return out

def evaluate_top(X_data,k):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    out = sess.run(tf.nn.top_k(topk,k), feed_dict={x: X_data})
    #out = sess.run(tf.reduce_mean(logits), feed_dict={x: X_data})
    return out
### Define your architecture here.
### Feel free to use as many code cells as needed.
EPOCHS = 100
BATCH_SIZE = 10

### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    saver.save(sess, './lenet')
    print("Model saved")
# Out:
# image_green\1213-2.jpg
# image_green\1217-2.jpg
# image_green\1219-2.jpg
# image_green\1221-2.jpg
# image_green\1222-2.jpg
# image_green\1224-2.jpg
# image_green\1227-2.jpg
# image_green\1228-2.jpg
# image_green\1229-2.jpg
# image_green\1230-2.jpg
# image_green\1231-2.jpg
# image_green\1232-2.jpg
# image_green\1233-2.jpg
# image_green\1401-2.jpg
# image_green\1402-2.jpg
# image_green\1403-2.jpg
# image_green\1404-2.jpg
# image_green\1405-2.jpg
# image_green\1406-2.jpg
# image_green\1408-2.jpg
# image_green\1409-2.jpg
# image_green\1410-2.jpg
# image_green\1411-2.jpg
# image_green\1413-2.jpg
# image_green\1415-2.jpg
# image_green\1416-2.jpg
# image_green\1417-2.jpg
# image_green\366-2.jpg
# image_green\367-2.jpg
# image_green\826-2.jpg
# image_green\827-2.jpg
# image_green\828-2.jpg
# image_green\829-2.jpg
# image_green\830-2.jpg
# image_green\831-2.jpg
# image_green\832-2.jpg
# image_green\833-2.jpg
# image_green\834-2.jpg
# image_green\835-2.jpg
# image_green\836-2.jpg
# image_green\837-2.jpg
# image_green\838-2.jpg
# image_green\839-2.jpg
# image_green\840-2.jpg
# image_other\381-0.jpg
# image_other\382-0.jpg
# image_other\383-0.jpg
# image_other\384-0.jpg
# image_other\385-0.jpg
# image_other\386-0.jpg
# image_other\387-0.jpg
# image_other\388-0.jpg
# image_other\389-0.jpg
# image_other\39-0.jpg
# image_other\390-0.jpg
# image_other\391-0.jpg
# image_other\392-0.jpg
# image_other\393-0.jpg
# image_other\394-0.jpg
# image_other\395-0.jpg
# image_other\396-0.jpg
# image_other\397-0.jpg
# image_other\398-0.jpg
# image_other\399-0.jpg
# image_other\40-0.jpg
# image_other\400-0.jpg
# image_other\401-0.jpg
# image_other\402-0.jpg
# image_other\403-0.jpg
# image_other\404-0.jpg
# image_other\405-0.jpg
# image_other\406-0.jpg
# image_other\407-0.jpg
# image_other\408-0.jpg
# image_other\409-0.jpg
# image_other\41-2.jpg
# image_other\410-0.jpg
# image_other\411-0.jpg
# image_other\412-0.jpg
# image_other\413-0.jpg
# image_other\414-0.jpg
# image_other\415-0.jpg
# image_other\416-0.jpg
# image_other\417-0.jpg
# image_other\418-0.jpg
# image_other\419-0.jpg
# image_other\42-2.jpg
# image_other\420-0.jpg
# image_other\421-0.jpg
# image_other\422-0.jpg
# image_other\423-0.jpg
# image_other\424-0.jpg
# image_other\425-0.jpg
# image_other\426-2.jpg
# image_other\427-2.jpg
# image_other\428-2.jpg
# image_other\429-2.jpg
# image_other\43-2.jpg
# image_other\430-2.jpg
# image_other\431-2.jpg
# image_other\432-2.jpg
# image_other\433-2.jpg
# image_other\434-2.jpg
# image_other\435-2.jpg
# image_other\436-2.jpg
# image_other\437-2.jpg
# image_other\438-2.jpg
# image_other\439-2.jpg
# image_other\44-2.jpg
# image_other\440-2.jpg
# image_other\441-2.jpg
# image_other\442-2.jpg
# image_other\443-2.jpg
# image_other\444-2.jpg
# image_other\445-2.jpg
# image_other\446-2.jpg
# image_other\447-2.jpg
# image_other\448-2.jpg
# image_other\449-2.jpg
# image_other\45-2.jpg
# image_other\450-2.jpg
# image_other\451-2.jpg
# image_other\452-2.jpg
# image_other\453-2.jpg
# image_other\454-2.jpg
# image_other\455-2.jpg
# image_other\456-2.jpg
# image_other\457-2.jpg
# image_other\458-2.jpg
# image_other\459-2.jpg
# image_other\46-2.jpg
# image_other\460-2.jpg
# image_other\461-2.jpg
# image_other\462-2.jpg
# image_other\463-2.jpg
# image_other\464-1.jpg
# image_other\465-1.jpg
# image_other\466-1.jpg
# image_other\467-1.jpg
# image_other\468-1.jpg
# image_other\469-1.jpg
# image_other\47-2.jpg
# image_other\470-1.jpg
# image_other\471-1.jpg
# image_other\472-1.jpg
# image_other\473-1.jpg
# image_other\474-0.jpg
# image_other\475-0.jpg
# image_other\476-0.jpg
# image_other\477-0.jpg
# image_other\478-0.jpg
# image_other\479-0.jpg
# image_other\48-2.jpg
# image_other\480-0.jpg
# image_other\481-0.jpg
# image_other\482-0.jpg
# image_other\483-0.jpg
# image_other\484-0.jpg
# image_other\485-0.jpg
# image_other\486-0.jpg
# image_other\487-0.jpg
# image_other\488-0.jpg
# image_other\489-0.jpg
# image_other\49-2.jpg
# image_other\490-0.jpg
# image_other\491-0.jpg
# image_other\492-0.jpg
# image_other\493-0.jpg
# image_other\494-0.jpg
# image_other\495-0.jpg
# image_other\496-0.jpg
# image_other\497-0.jpg
# image_other\498-0.jpg
# image_other\499-0.jpg
# image_other\50-2.jpg
# image_other\500-0.jpg
# image_other\501-0.jpg
# image_other\502-0.jpg
# image_other\503-0.jpg
# image_other\504-0.jpg
# image_other\505-0.jpg
# image_other\506-0.jpg
# image_other\507-0.jpg
# image_other\508-0.jpg
# image_other\509-0.jpg
# image_other\51-2.jpg
# image_other\510-0.jpg
# image_other\511-0.jpg
# image_other\512-0.jpg
# image_other\513-0.jpg
# image_other\514-0.jpg
# image_other\515-0.jpg
# image_other\516-0.jpg
# image_other\517-0.jpg
# image_other\518-0.jpg
# image_other\519-0.jpg
# image_other\52-2.jpg
# image_other\520-0.jpg
# image_other\521-0.jpg
# image_other\522-2.jpg
# image_other\523-2.jpg
# image_other\524-2.jpg
# image_other\525-2.jpg
# image_other\526-2.jpg
# image_other\527-2.jpg
# image_other\528-2.jpg
# image_other\529-2.jpg
# image_other\53-2.jpg
# image_other\530-2.jpg
# image_other\531-2.jpg
# image_other\532-2.jpg
# image_other\533-2.jpg
# image_other\534-2.jpg
# image_other\535-2.jpg
# image_other\536-2.jpg
# image_other\537-2.jpg
# image_other\538-2.jpg
# image_other\539-2.jpg
# image_other\54-2.jpg
# image_other\540-2.jpg
# image_other\541-2.jpg
# image_other\542-2.jpg
# image_other\543-2.jpg
# image_other\544-2.jpg
# image_other\545-2.jpg
# image_other\546-2.jpg
# image_other\547-2.jpg
# image_other\548-2.jpg
# image_other\549-2.jpg
# image_other\55-2.jpg
# image_other\550-2.jpg
# image_other\551-2.jpg
# image_other\552-2.jpg
# image_other\553-2.jpg
# image_other\554-2.jpg
# image_other\555-2.jpg
# image_other\556-2.jpg
# image_other\557-2.jpg
# image_other\558-2.jpg
# image_other\559-2.jpg
# image_other\56-2.jpg
# image_other\560-1.jpg
# image_other\561-1.jpg
# image_other\562-1.jpg
# image_other\563-1.jpg
# image_other\564-1.jpg
# image_other\565-1.jpg
# image_other\566-1.jpg
# image_other\567-1.jpg
# image_other\568-1.jpg
# image_other\569-1.jpg
# image_other\57-2.jpg
# image_other\570-0.jpg
# image_other\571-0.jpg
# image_other\572-0.jpg
# image_other\573-0.jpg
# image_other\574-0.jpg
# image_other\575-0.jpg
# image_other\576-0.jpg
# image_other\577-0.jpg
# image_other\578-0.jpg
# image_other\579-0.jpg
# image_other\58-2.jpg
# image_other\580-0.jpg
# image_other\581-0.jpg
# image_other\582-0.jpg
# image_other\583-0.jpg
# image_other\584-0.jpg
# image_other\585-0.jpg
# image_other\586-0.jpg
# image_other\587-0.jpg
# image_other\588-0.jpg
# image_other\589-0.jpg
# image_other\59-2.jpg
# image_other\590-0.jpg
# image_other\591-0.jpg
# image_other\592-0.jpg
# image_other\593-0.jpg
# image_other\594-0.jpg
# image_other\595-0.jpg
# image_other\596-0.jpg
# image_other\597-0.jpg
# image_other\598-0.jpg
# image_other\599-0.jpg
# image_other\60-2.jpg
# image_other\600-0.jpg
# image_other\601-0.jpg
# image_other\602-0.jpg
# image_other\603-0.jpg
# image_other\604-0.jpg
# image_other\605-0.jpg
# image_other\606-0.jpg
# image_other\607-0.jpg
# image_other\608-0.jpg
# image_other\609-0.jpg
# image_other\61-2.jpg
# image_other\610-0.jpg
# image_other\611-0.jpg
# image_other\612-0.jpg
# image_other\613-0.jpg
# image_other\614-0.jpg
# image_other\615-0.jpg
# image_other\616-0.jpg
# image_other\617-0.jpg
# image_other\618-0.jpg
# image_other\619-2.jpg
# image_other\62-2.jpg
# image_other\620-2.jpg
# image_other\621-2.jpg
# image_other\622-2.jpg
# image_other\623-2.jpg
# image_other\624-2.jpg
# image_other\625-2.jpg
# image_other\626-2.jpg
# image_other\627-2.jpg
# image_other\628-2.jpg
# image_other\629-2.jpg
# image_other\63-2.jpg
# image_other\630-2.jpg
# image_other\631-2.jpg
# image_other\632-2.jpg
# image_other\633-2.jpg
# image_other\634-2.jpg
# image_other\635-2.jpg
# image_other\636-2.jpg
# image_other\637-2.jpg
# image_other\638-2.jpg
# image_other\639-2.jpg
# image_other\64-2.jpg
# image_other\640-2.jpg
# image_other\641-2.jpg
# image_other\642-2.jpg
# image_other\643-2.jpg
# image_other\644-2.jpg
# image_other\645-2.jpg
# image_other\646-2.jpg
# image_other\647-2.jpg
# image_other\648-2.jpg
# image_other\649-2.jpg
# image_other\65-2.jpg
# image_other\650-2.jpg
# image_other\651-2.jpg
# image_other\652-2.jpg
# image_other\653-2.jpg
# image_other\654-2.jpg
# image_other\655-2.jpg
# image_other\656-1.jpg
# image_other\657-1.jpg
# image_other\658-1.jpg
# image_other\659-1.jpg
# image_other\66-2.jpg
# image_other\660-1.jpg
# image_other\661-1.jpg
# image_other\662-1.jpg
# image_other\663-1.jpg
# image_other\664-1.jpg
# image_other\665-1.jpg
# image_other\666-0.jpg
# image_other\667-0.jpg
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-efd7e557c793> in <module>()
#      28 addfiletolist(rootdir,X_all,y_all,2)
#      29 rootdir = 'image_other'
# ---> 30 addfiletolist(rootdir,X_all,y_all,3)
#      31
#      32 import numpy as np
#
# <ipython-input-2-efd7e557c793> in addfiletolist(rootdir, img, val, id)
#      11         if os.path.isfile(path):
#      12             print(path)
# ---> 13             img1 = Image.open(path)
#      14             img1=img1.resize((32,32))
#      15             arr1=np.array(img1)
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2555         exclusive_fp = True
#    2556
# -> 2557     prefix = fp.read(16)
#    2558
#    2559     preinit()
#
# OSError: [Errno 22] Invalid argument
